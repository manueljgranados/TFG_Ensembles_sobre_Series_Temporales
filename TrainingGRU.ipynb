# %%
#Descarga de índices bursátiles desde Yahoo Finances.
# -- Sólo descomentar una vez, el resto de usos se pueden hacer desde el fichero descargado
"""
import yfinance as yf

tickers = [
    "^GSPC","^IXIC","^DJI","^RUT",
    "^FTSE","^GDAXI","^FCHI","^125904-USD-STRD","^IBEX",
    "^N225","^HSI","000001.SS","^KS11","^BSESN",
    "^GSPTSE","^BVSP","^MXX","^MERV",
    "^AXJO","^NZ50",
    "ES=F","NQ=F","YM=F","ZT=F","^VIX"
]

# Descarga de cierres diarios sin agrupar por ticker
data = yf.download(
    tickers,
    start="2005-01-01",
    end="2025-01-02"
)

cierres = data["Close"]  # DataFrame con cada ticker como columna
cierres.to_csv("./data/cierres_diarios_2005_2025.csv")
"""

# %%
#Uso de los datos descargados para entrenamiento
# -- Asegurarse de enrutamiento y nombre de fichero correctos

import pandas as pd
df = pd.read_csv('./data/cierres_diarios_2005_2025n.csv', parse_dates=['Date'], index_col='Date')

# %%
# Preparación de los datos

# Eliminación de nulos
df.ffill(inplace=True)
df.bfill(inplace=True)

# Split en crudo (¡antes de escalar!)
n = len(df)
train_raw = df.iloc[:int(n*0.7)]
val_raw   = df.iloc[int(n*0.7):int(n*0.9)]
test_raw  = df.iloc[int(n*0.9):]

# Ajustar scaler SOLO con TRAIN
from sklearn.preprocessing import MinMaxScaler
from joblib import dump
scaler = MinMaxScaler()
scaler.fit(train_raw)  # <- fit solo con train

# Transformar cada split con ese scaler
import pandas as pd
train_df = pd.DataFrame(scaler.transform(train_raw), index=train_raw.index, columns=train_raw.columns).astype("float32")
val_df   = pd.DataFrame(scaler.transform(val_raw),   index=val_raw.index,   columns=val_raw.columns).astype("float32")
test_df  = pd.DataFrame(scaler.transform(test_raw),  index=test_raw.index,  columns=test_raw.columns).astype("float32")

# Guardar scaler para escenarios S/M/L
dump(scaler, "scaler_modelos.joblib")


import tensorflow as tf

def make_dataset(data, window_size, horizon, batch_size=32, shuffle=True):
    ds = tf.keras.preprocessing.timeseries_dataset_from_array(
        data=data.values,
        targets=None,
        sequence_length=window_size + horizon,
        sequence_stride=1,
        batch_size=batch_size,
        shuffle=shuffle
    )
    return ds.map(
        lambda seq: (
            tf.cast(seq[:, :window_size, :], tf.float32),
            tf.cast(seq[:, window_size:, :], tf.float32)
        )
    )


# Recreamos datasets con shuffle=False para val/test:
train_dss = make_dataset(train_df, window_size=20,  horizon=1,  batch_size=32, shuffle=True)
val_dss   = make_dataset(val_df,   window_size=20,  horizon=1,  batch_size=32, shuffle=False)
test_dss  = make_dataset(test_df,  window_size=20,  horizon=1,  batch_size=32, shuffle=False)

train_dsm = make_dataset(train_df, window_size=60,  horizon=5,  batch_size=32, shuffle=True)
val_dsm   = make_dataset(val_df,   window_size=60,  horizon=5,  batch_size=32, shuffle=False)
test_dsm  = make_dataset(test_df,  window_size=60,  horizon=5,  batch_size=32, shuffle=False)

train_dsl = make_dataset(train_df, window_size=120, horizon=20, batch_size=32, shuffle=True)
val_dsl   = make_dataset(val_df,   window_size=120, horizon=20, batch_size=32, shuffle=False)
test_dsl  = make_dataset(test_df,  window_size=120, horizon=20, batch_size=32, shuffle=False)
# Out:
# 2025-09-19 08:46:11.518577: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2025-09-19 08:46:11.518608: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-09-19 08:46:11.518613: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-09-19 08:46:11.518630: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-09-19 08:46:11.518645: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# =========================================================
# GRU + Huber (sweep delta)
# Selección de δ basada en métrica común: val_log_cosh
# Grid de δ calibrado con cuantiles de |e| (baseline persistencia) en VAL
# =========================================================
import os
import numpy as np
import tensorflow as tf
from typing import List, Tuple
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, GRU, Dense, Dropout, RepeatVector, TimeDistributed, LayerNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# ---------- Scaler único (MinMax) ----------
try:
    scaler
except NameError:
    from joblib import load
    scaler = load("scaler_modelos.joblib")

# ---------- Config ----------
MODEL_DIR = "./models_gru_huber_sweep"
os.makedirs(MODEL_DIR, exist_ok=True)

# EPS para métricas within (escala normalizada [0,1])
EPS_LIST = [0.005, 0.01, 0.02, 0.05, 0.1]

# ---------- Utils ----------
def infer_shapes_from_dataset(ds: tf.data.Dataset) -> Tuple[int, int, int]:
    for xb, yb in ds.take(1):
        w = int(xb.shape[1])
        f = int(xb.shape[2])
        h = int(yb.shape[1])
        return w, f, h
    raise ValueError("Dataset vacío")

def _eps_tag(x: float) -> str:
    s = f"{x:.10g}"
    s = s.rstrip('0').rstrip('.') if '.' in s else s
    return s.replace('.', '_')

# ---------- Métricas ----------
def log_cosh_metric(y_true, y_pred):
    e = tf.cast(y_pred, tf.float32) - tf.cast(y_true, tf.float32)
    ae = tf.abs(e)
    return tf.reduce_mean(ae + tf.nn.softplus(-2.0 * ae) - tf.math.log(2.0))
log_cosh_metric.__name__ = "log_cosh"

def make_within_eps_vector_metric(eps_vec: np.ndarray, tag: str):
    eps_tf = tf.constant(eps_vec.astype(np.float32), dtype=tf.float32)  # (F,)
    def within_eps(y_true, y_pred):
        diff = tf.abs(tf.cast(y_pred, tf.float32) - tf.cast(y_true, tf.float32))  # (B,H,F)
        thr  = eps_tf[tf.newaxis, tf.newaxis, :]
        hit  = tf.cast(diff <= thr, tf.float32)
        return tf.reduce_mean(hit)
    within_eps.__name__ = tag
    return within_eps

def build_within_metrics_minmax(scaler, eps_list: List[float], n_features: int):
    if not hasattr(scaler, "data_range_"):
        raise ValueError("Se esperaba MinMaxScaler con data_range_.")
    if len(scaler.data_range_) != n_features:
        raise ValueError("scaler.data_range_ no coincide con n_features.")
    metrics = [log_cosh_metric]
    for e in eps_list:
        eps_vec = np.full((n_features,), float(e), dtype=np.float32)
        tag = f"within_eps_{_eps_tag(e)}"
        metrics.append(make_within_eps_vector_metric(eps_vec, tag))
    return metrics

def _get_metric_value_relaxed(res: dict, base_name: str):
    """
    Devuelve res[base_name] si existe; si no, busca cualquier clave que empiece por base_name + '_'
    (para cubrir sufijos que Keras añade como '_1', '_2', etc.). Si no hay match, devuelve NaN.
    """
    if base_name in res and np.isfinite(res[base_name]):
        return float(res[base_name])
    # Busca con sufijo
    for k, v in res.items():
        if k.startswith(base_name + "_"):
            try:
                v = float(v)
                if np.isfinite(v):
                    return v
            except Exception:
                pass
    return float("nan")

def compute_autc_from_results(res: dict, eps_list) -> float:
    eps = np.array(sorted(eps_list), dtype=np.float64)
    acc = []
    missing = []
    for e in eps:
        base = f"within_eps_{_eps_tag(e)}"
        val = _get_metric_value_relaxed(res, base)
        acc.append(val)
        if not np.isfinite(val):
            missing.append(base)
    acc = np.array(acc, dtype=np.float64)

    # Debug útil si algo falla
    if missing:
        print("[AUTC] Aviso: no se encontraron métricas:", missing)
        print("[AUTC] Claves disponibles:", sorted([k for k in res.keys() if "within_eps_" in k]))

    mask = np.isfinite(acc)
    if mask.sum() < 2:
        return float("nan")

    return float(np.trapz(acc[mask], eps[mask]) / (eps[mask][-1] - eps[mask][0]))


# ---------- Modelo GRU ----------
def build_gru_point_model(window: int, n_features: int, horizon: int,
                          units_enc: int = 128, units_dec: int = 64,
                          p_drop_enc: float = 0.2, p_drop_dec: float = 0.2) -> Model:
    inp = Input(shape=(window, n_features))
    x = GRU(units_enc, return_sequences=False)(inp)
    x = LayerNormalization()(x)
    x = Dropout(p_drop_enc)(x)

    x = RepeatVector(horizon)(x)
    x = GRU(units_dec, return_sequences=True)(x)
    x = LayerNormalization()(x)
    x = Dropout(p_drop_dec)(x)

    out_lin = TimeDistributed(Dense(n_features))(x)  # (B,H,F)
    return Model(inp, out_lin, name=f"GRU_POINT_H{horizon}_F{n_features}")

# ---------- Pérdida Huber ----------
def make_huber_loss(delta: float):
    base = tf.keras.losses.Huber(delta=float(delta))
    def huber_loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32); y_pred = tf.cast(y_pred, tf.float32)
        return base(y_true, y_pred)
    huber_loss.__name__ = f"huber_delta_{_eps_tag(delta)}"
    return huber_loss

# ---------- Calibración del array de δ ----------
def estimate_error_quantiles_persistence(val_ds: tf.data.Dataset, max_batches: int = 256):
    """Cuantiles de |e| en VAL usando como base la persistencia (y_hat = último paso repetido)."""
    errs = []
    taken = 0
    for xb, yb in val_ds:
        # xb: (B, W, F), yb: (B, H, F)
        yhat = tf.repeat(xb[:, -1:, :], repeats=tf.shape(yb)[1], axis=1)  # (B,H,F)
        e = tf.abs(tf.cast(yb, tf.float32) - tf.cast(yhat, tf.float32)).numpy().ravel()
        errs.append(e)
        taken += 1
        if taken >= max_batches:
            break
    if not errs:
        return [0.01, 0.02, 0.05, 0.1]  # fallback
    e = np.concatenate(errs)
    qs = np.quantile(e, [0.5, 0.75, 0.9, 0.95])
    return list(qs)

def build_delta_grid(val_ds: tf.data.Dataset):
    base = [0.01, 0.02, 0.05, 0.1]                # base pequeña estable
    qs = estimate_error_quantiles_persistence(val_ds, max_batches=256)  # p50, p75, p90, p95
    cand = sorted(set(base + qs))
    # recorte por seguridad al rango normalizado
    cand = [float(np.clip(c, 1e-4, 0.5)) for c in cand]
    cand = sorted(set(cand))
    print("\nGrid δ (calibrado con cuantiles |e| en VAL):", cand)
    return cand

# ---------- Entrenamiento para un δ (callbacks en val_log_cosh) ----------
def train_for_delta(train_ds: tf.data.Dataset,
                    val_ds: tf.data.Dataset,
                    delta: float,
                    scenario_tag: str,
                    scaler) -> tuple[Model, float, str]:
    w, f, h = infer_shapes_from_dataset(train_ds)
    model = build_gru_point_model(w, f, h)

    metrics = build_within_metrics_minmax(scaler, EPS_LIST, n_features=f)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4, clipnorm=1.0),
        loss=make_huber_loss(delta),
        metrics=metrics
    )

    ckpt_path = os.path.join(
        MODEL_DIR, f"gru_huber_w{w}_h{h}_delta{_eps_tag(delta)}{scenario_tag}.keras"
    )

    callbacks = [
        tf.keras.callbacks.TerminateOnNaN(),
        # >>> monitor común e independiente de δ <<<
        EarlyStopping(monitor="val_log_cosh", mode="min", patience=15, restore_best_weights=True),
        ModelCheckpoint(ckpt_path, monitor="val_log_cosh", mode="min", save_best_only=True)
    ]

    hist = model.fit(train_ds, validation_data=val_ds, epochs=160, callbacks=callbacks, verbose=1)
    vlc = np.array(hist.history.get("val_log_cosh", []), dtype=np.float32)
    vlc = vlc[np.isfinite(vlc)]
    best_val_logcosh = float(np.min(vlc)) if vlc.size > 0 else np.inf

    vll = np.array(hist.history.get("val_loss", []), dtype=np.float32)
    vll = vll[np.isfinite(vll)]
    best_val_huber = float(np.min(vll)) if vll.size > 0 else np.inf
    
    return model, best_val_logcosh, best_val_huber, ckpt_path

# ---------- Barrido de deltas (selección por val_log_cosh) ----------
def sweep_deltas(train_ds, val_ds, scenario_tag: str, scaler) -> tuple[Model, float, str]:
    deltas = build_delta_grid(val_ds)
    print(f"\n=== Barrido Huber delta {scenario_tag} (GRU) ===")
    results = []  # (delta, best_val_logcosh, best_val_huber, ckpt_path)

    best_score = np.inf; best_ckpt=None; best_delta=None; best_model=None
    
    for d in deltas:
        print(f"\n--- Entrenando δ={d} ---")
        model, val_logcosh, val_huber, ckpt_path = train_for_delta(train_ds, val_ds, d, scenario_tag, scaler)
        print(f"  -> min val_log_cosh={val_logcosh:.12f} | min val_huber={val_huber:.12f}")
        results.append((d, val_logcosh, val_huber, ckpt_path))
        if val_logcosh < best_score:  # selección por métrica común
            best_score, best_ckpt, best_delta, best_model = val_logcosh, ckpt_path, d, model

    # Carga el mejor checkpoint (Flask-ready)
    if best_ckpt:
        best_model = tf.keras.models.load_model(best_ckpt, compile=False)

    # Tabla ordenada para inspección
    results_sorted = sorted(results, key=lambda x: x[1])
    print("\nTabla val_log_cosh(min) por δ (orden asc):")
    for d, v_log, v_hub, _ in results_sorted:
        print(f"  δ={d:>8g}: val_log_cosh={v_log:.12f} | val_huber={v_hub:.12f}")
    print(f"\n>>> Mejor δ por val_log_cosh: {best_delta} (val_log_cosh={best_score:.12f})")
    return best_model, best_delta, best_ckpt

# ---------- Evaluación en TEST ----------
def evaluate_on_test(model: tf.keras.Model, ds: tf.data.Dataset, best_delta: float, scaler):
    if (model is None) or (best_delta is None) or (not np.isfinite(best_delta)):
        print("  [AVISO] No se pudo entrenar un modelo válido.")
        return
    _, f, _ = infer_shapes_from_dataset(ds)
    metrics = build_within_metrics_minmax(scaler, EPS_LIST, n_features=f)
    model.compile(optimizer="adam", loss=make_huber_loss(best_delta), metrics=metrics)

    res = model.evaluate(ds, return_dict=True, verbose=0)
    print("  loss (Huber):              {:.6f}".format(res.get("loss", float("nan"))))
    print("  log_cosh:                  {:.6f}".format(res.get("log_cosh", float("nan"))))
    for e in EPS_LIST:
        key = f"within_eps_{_eps_tag(e)}"
        print(f"  {key:26s}: {res.get(key, float('nan')):.6f}")
    autc = compute_autc_from_results(res, EPS_LIST)
    eps_min, eps_max = float(min(EPS_LIST)), float(max(EPS_LIST))
    print(f"  AUTC[{eps_min:.3f}–{eps_max:.3f}]:         {autc:.6f}")

# ================== EJECUCIÓN: TRES ESCENARIOS ==================
# Usa tus datasets ya creados sin shuffle en val/test:
#   train_dss/val_dss/test_dss, train_dsm/val_dsm/test_dsm, train_dsl/val_dsl/test_dsl

# Escenario S (20→1)
model_s, delta_s, path_s = sweep_deltas(train_dss, val_dss, scenario_tag="_S", scaler=scaler)
print("\nResultados TEST - Escenario S (GRU)")
evaluate_on_test(model_s, test_dss, best_delta=delta_s, scaler=scaler)

# Escenario M (60→5)
model_m, delta_m, path_m = sweep_deltas(train_dsm, val_dsm, scenario_tag="_M", scaler=scaler)
print("\nResultados TEST - Escenario M (GRU)")
evaluate_on_test(model_m, test_dsm, best_delta=delta_m, scaler=scaler)

# Escenario L (120→20)
model_l, delta_l, path_l = sweep_deltas(train_dsl, val_dsl, scenario_tag="_L", scaler=scaler)
print("\nResultados TEST - Escenario L (GRU)")
evaluate_on_test(model_l, test_dsl, best_delta=delta_l, scaler=scaler)

print("\n=== Mejor δ por escenario (GRU, métrica común: val_log_cosh) ===")
print(f"  S: {delta_s}  -> {path_s}")
print(f"  M: {delta_m}  -> {path_m}")
print(f"  L: {delta_l}  -> {path_l}")
# Out:
# Grid δ (calibrado con cuantiles |e| en VAL): [0.00853496789932251, 0.01, 0.017357412725687027, 0.02, 0.03049677610397339, 0.04116208553314208, 0.05, 0.1]
#
# === Barrido Huber delta _S (GRU) ===
#
# --- Entrenando δ=0.00853496789932251 ---
# Epoch 1/160
# 2025-09-19 08:46:13.377450: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-09-19 08:46:13.884227: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - log_cosh: 0.3193 - loss: 0.0060 - within_eps_0_005: 0.0050 - within_eps_0_01: 0.0101 - within_eps_0_02: 0.0196 - within_eps_0_05: 0.0482 - within_eps_0_1: 0.0969 - val_log_cosh: 0.1472 - val_loss: 0.0038 - val_within_eps_0_005: 0.0057 - val_within_eps_0_01: 0.0107 - val_within_eps_0_02: 0.0226 - val_within_eps_0_05: 0.0638 - val_within_eps_0_1: 0.1322
# Epoch 2/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - log_cosh: 0.1350 - loss: 0.0037 - within_eps_0_005: 0.0068 - within_eps_0_01: 0.0137 - within_eps_0_02: 0.0293 - within_eps_0_05: 0.0734 - within_eps_0_1: 0.1454 - val_log_cosh: 0.1072 - val_loss: 0.0031 - val_within_eps_0_005: 0.0103 - val_within_eps_0_01: 0.0199 - val_within_eps_0_02: 0.0392 - val_within_eps_0_05: 0.1020 - val_within_eps_0_1: 0.1871
# Epoch 3/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - log_cosh: 0.1007 - loss: 0.0031 - within_eps_0_005: 0.0089 - within_eps_0_01: 0.0174 - within_eps_0_02: 0.0339 - within_eps_0_05: 0.0859 - within_eps_0_1: 0.1728 - val_log_cosh: 0.0860 - val_loss: 0.0027 - val_within_eps_0_005: 0.0095 - val_within_eps_0_01: 0.0190 - val_within_eps_0_02: 0.0385 - val_within_eps_0_05: 0.0951 - val_within_eps_0_1: 0.1989
# Epoch 4/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - log_cosh: 0.0730 - loss: 0.0026 - within_eps_0_005: 0.0112 - within_eps_0_01: 0.0221 - within_eps_0_02: 0.0430 - within_eps_0_05: 0.1055 - within_eps_0_1: 0.2066 - val_log_cosh: 0.0826 - val_loss: 0.0026 - val_within_eps_0_005: 0.0081 - val_within_eps_0_01: 0.0175 - val_within_eps_0_02: 0.0375 - val_within_eps_0_05: 0.1117 - val_within_eps_0_1: 0.2401
# Epoch 5/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - log_cosh: 0.0499 - loss: 0.0021 - within_eps_0_005: 0.0134 - within_eps_0_01: 0.0254 - within_eps_0_02: 0.0506 - within_eps_0_05: 0.1271 - within_eps_0_1: 0.2538 - val_log_cosh: 0.0696 - val_loss: 0.0023 - val_within_eps_0_005: 0.0126 - val_within_eps_0_01: 0.0235 - val_within_eps_0_02: 0.0482 - val_within_eps_0_05: 0.1270 - val_within_eps_0_1: 0.2744
# Epoch 6/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - log_cosh: 0.0344 - loss: 0.0017 - within_eps_0_005: 0.0160 - within_eps_0_01: 0.0318 - within_eps_0_02: 0.0630 - within_eps_0_05: 0.1573 - within_eps_0_1: 0.3091 - val_log_cosh: 0.0700 - val_loss: 0.0023 - val_within_eps_0_005: 0.0120 - val_within_eps_0_01: 0.0251 - val_within_eps_0_02: 0.0503 - val_within_eps_0_05: 0.1363 - val_within_eps_0_1: 0.2739
# Epoch 7/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - log_cosh: 0.0232 - loss: 0.0014 - within_eps_0_005: 0.0196 - within_eps_0_01: 0.0384 - within_eps_0_02: 0.0780 - within_eps_0_05: 0.1964 - within_eps_0_1: 0.3795 - val_log_cosh: 0.0607 - val_loss: 0.0021 - val_within_eps_0_005: 0.0159 - val_within_eps_0_01: 0.0330 - val_within_eps_0_02: 0.0647 - val_within_eps_0_05: 0.1648 - val_within_eps_0_1: 0.3226
# Epoch 8/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - log_cosh: 0.0156 - loss: 0.0011 - within_eps_0_005: 0.0256 - within_eps_0_01: 0.0507 - within_eps_0_02: 0.1007 - within_eps_0_05: 0.2436 - within_eps_0_1: 0.4556 - val_log_cosh: 0.0659 - val_loss: 0.0022 - val_within_eps_0_005: 0.0164 - val_within_eps_0_01: 0.0299 - val_within_eps_0_02: 0.0600 - val_within_eps_0_05: 0.1482 - val_within_eps_0_1: 0.3016
# Epoch 9/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - log_cosh: 0.0114 - loss: 9.6849e-04 - within_eps_0_005: 0.0295 - within_eps_0_01: 0.0584 - within_eps_0_02: 0.1162 - within_eps_0_05: 0.2808 - within_eps_0_1: 0.5234 - val_log_cosh: 0.0616 - val_loss: 0.0021 - val_within_eps_0_005: 0.0177 - val_within_eps_0_01: 0.0365 - val_within_eps_0_02: 0.0737 - val_within_eps_0_05: 0.1823 - val_within_eps_0_1: 0.3363
# Epoch 10/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - log_cosh: 0.0084 - loss: 8.1935e-04 - within_eps_0_005: 0.0339 - within_eps_0_01: 0.0697 - within_eps_0_02: 0.1381 - within_eps_0_05: 0.3290 - within_eps_0_1: 0.5954 - val_log_cosh: 0.0688 - val_loss: 0.0022 - val_within_eps_0_005: 0.0167 - val_within_eps_0_01: 0.0324 - val_within_eps_0_02: 0.0667 - val_within_eps_0_05: 0.1597 - val_within_eps_0_1: 0.3010
# Epoch 11/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - log_cosh: 0.0069 - loss: 7.2813e-04 - within_eps_0_005: 0.0385 - within_eps_0_01: 0.0787 - within_eps_0_02: 0.1571 - within_eps_0_05: 0.3724 - within_eps_0_1: 0.6515 - val_log_cosh: 0.0547 - val_loss: 0.0019 - val_within_eps_0_005: 0.0196 - val_within_eps_0_01: 0.0374 - val_within_eps_0_02: 0.0721 - val_within_eps_0_05: 0.1881 - val_within_eps_0_1: 0.3654
# Epoch 12/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - log_cosh: 0.0057 - loss: 6.5704e-04 - within_eps_0_005: 0.0433 - within_eps_0_01: 0.0854 - within_eps_0_02: 0.1716 - within_eps_0_05: 0.4096 - within_eps_0_1: 0.6974 - val_log_cosh: 0.0569 - val_loss: 0.0020 - val_within_eps_0_005: 0.0200 - val_within_eps_0_01: 0.0397 - val_within_eps_0_02: 0.0789 - val_within_eps_0_05: 0.1849 - val_within_eps_0_1: 0.3293
# Epoch 13/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0050 - loss: 6.1242e-04 - within_eps_0_005: 0.0464 - within_eps_0_01: 0.0928 - within_eps_0_02: 0.1844 - within_eps_0_05: 0.4322 - within_eps_0_1: 0.7282 - val_log_cosh: 0.0584 - val_loss: 0.0020 - val_within_eps_0_005: 0.0206 - val_within_eps_0_01: 0.0392 - val_within_eps_0_02: 0.0723 - val_within_eps_0_05: 0.1752 - val_within_eps_0_1: 0.3354
# Epoch 14/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - log_cosh: 0.0047 - loss: 5.8276e-04 - within_eps_0_005: 0.0516 - within_eps_0_01: 0.1004 - within_eps_0_02: 0.1961 - within_eps_0_05: 0.4595 - within_eps_0_1: 0.7457 - val_log_cosh: 0.0540 - val_loss: 0.0019 - val_within_eps_0_005: 0.0193 - val_within_eps_0_01: 0.0371 - val_within_eps_0_02: 0.0747 - val_within_eps_0_05: 0.1973 - val_within_eps_0_1: 0.3510
# Epoch 15/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0044 - loss: 5.6695e-04 - within_eps_0_005: 0.0507 - within_eps_0_01: 0.1034 - within_eps_0_02: 0.2032 - within_eps_0_05: 0.4693 - within_eps_0_1: 0.7561 - val_log_cosh: 0.0544 - val_loss: 0.0019 - val_within_eps_0_005: 0.0191 - val_within_eps_0_01: 0.0382 - val_within_eps_0_02: 0.0806 - val_within_eps_0_05: 0.1916 - val_within_eps_0_1: 0.3513
# Epoch 16/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0041 - loss: 5.3564e-04 - within_eps_0_005: 0.0557 - within_eps_0_01: 0.1111 - within_eps_0_02: 0.2182 - within_eps_0_05: 0.4950 - within_eps_0_1: 0.7803 - val_log_cosh: 0.0527 - val_loss: 0.0019 - val_within_eps_0_005: 0.0218 - val_within_eps_0_01: 0.0457 - val_within_eps_0_02: 0.0910 - val_within_eps_0_05: 0.2033 - val_within_eps_0_1: 0.3424
# Epoch 17/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0039 - loss: 5.2568e-04 - within_eps_0_005: 0.0554 - within_eps_0_01: 0.1109 - within_eps_0_02: 0.2180 - within_eps_0_05: 0.4977 - within_eps_0_1: 0.7857 - val_log_cosh: 0.0517 - val_loss: 0.0019 - val_within_eps_0_005: 0.0217 - val_within_eps_0_01: 0.0416 - val_within_eps_0_02: 0.0834 - val_within_eps_0_05: 0.2020 - val_within_eps_0_1: 0.3601
# Epoch 18/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0037 - loss: 5.0977e-04 - within_eps_0_005: 0.0574 - within_eps_0_01: 0.1143 - within_eps_0_02: 0.2251 - within_eps_0_05: 0.5136 - within_eps_0_1: 0.7961 - val_log_cosh: 0.0543 - val_loss: 0.0020 - val_within_eps_0_005: 0.0182 - val_within_eps_0_01: 0.0385 - val_within_eps_0_02: 0.0793 - val_within_eps_0_05: 0.1863 - val_within_eps_0_1: 0.3492
# Epoch 19/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0034 - loss: 4.8595e-04 - within_eps_0_005: 0.0595 - within_eps_0_01: 0.1182 - within_eps_0_02: 0.2356 - within_eps_0_05: 0.5321 - within_eps_0_1: 0.8137 - val_log_cosh: 0.0493 - val_loss: 0.0018 - val_within_eps_0_005: 0.0236 - val_within_eps_0_01: 0.0482 - val_within_eps_0_02: 0.0948 - val_within_eps_0_05: 0.2134 - val_within_eps_0_1: 0.3702
# Epoch 20/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0032 - loss: 4.7281e-04 - within_eps_0_005: 0.0642 - within_eps_0_01: 0.1251 - within_eps_0_02: 0.2431 - within_eps_0_05: 0.5424 - within_eps_0_1: 0.8249 - val_log_cosh: 0.0519 - val_loss: 0.0019 - val_within_eps_0_005: 0.0207 - val_within_eps_0_01: 0.0420 - val_within_eps_0_02: 0.0862 - val_within_eps_0_05: 0.2035 - val_within_eps_0_1: 0.3562
# Epoch 21/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0031 - loss: 4.6337e-04 - within_eps_0_005: 0.0639 - within_eps_0_01: 0.1257 - within_eps_0_02: 0.2488 - within_eps_0_05: 0.5531 - within_eps_0_1: 0.8293 - val_log_cosh: 0.0535 - val_loss: 0.0019 - val_within_eps_0_005: 0.0240 - val_within_eps_0_01: 0.0471 - val_within_eps_0_02: 0.0918 - val_within_eps_0_05: 0.1969 - val_within_eps_0_1: 0.3530
# Epoch 22/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0031 - loss: 4.6013e-04 - within_eps_0_005: 0.0637 - within_eps_0_01: 0.1265 - within_eps_0_02: 0.2458 - within_eps_0_05: 0.5522 - within_eps_0_1: 0.8324 - val_log_cosh: 0.0510 - val_loss: 0.0019 - val_within_eps_0_005: 0.0227 - val_within_eps_0_01: 0.0434 - val_within_eps_0_02: 0.0844 - val_within_eps_0_05: 0.2108 - val_within_eps_0_1: 0.3586
# Epoch 23/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0028 - loss: 4.4170e-04 - within_eps_0_005: 0.0673 - within_eps_0_01: 0.1330 - within_eps_0_02: 0.2614 - within_eps_0_05: 0.5680 - within_eps_0_1: 0.8433 - val_log_cosh: 0.0477 - val_loss: 0.0018 - val_within_eps_0_005: 0.0232 - val_within_eps_0_01: 0.0480 - val_within_eps_0_02: 0.0897 - val_within_eps_0_05: 0.2015 - val_within_eps_0_1: 0.3846
# Epoch 24/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0028 - loss: 4.3347e-04 - within_eps_0_005: 0.0681 - within_eps_0_01: 0.1357 - within_eps_0_02: 0.2633 - within_eps_0_05: 0.5793 - within_eps_0_1: 0.8510 - val_log_cosh: 0.0494 - val_loss: 0.0018 - val_within_eps_0_005: 0.0224 - val_within_eps_0_01: 0.0452 - val_within_eps_0_02: 0.0928 - val_within_eps_0_05: 0.2190 - val_within_eps_0_1: 0.3810
# Epoch 25/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0026 - loss: 4.2309e-04 - within_eps_0_005: 0.0692 - within_eps_0_01: 0.1384 - within_eps_0_02: 0.2688 - within_eps_0_05: 0.5865 - within_eps_0_1: 0.8576 - val_log_cosh: 0.0489 - val_loss: 0.0018 - val_within_eps_0_005: 0.0252 - val_within_eps_0_01: 0.0509 - val_within_eps_0_02: 0.1003 - val_within_eps_0_05: 0.2230 - val_within_eps_0_1: 0.3939
# Epoch 26/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0027 - loss: 4.2381e-04 - within_eps_0_005: 0.0700 - within_eps_0_01: 0.1401 - within_eps_0_02: 0.2741 - within_eps_0_05: 0.5916 - within_eps_0_1: 0.8546 - val_log_cosh: 0.0483 - val_loss: 0.0018 - val_within_eps_0_005: 0.0252 - val_within_eps_0_01: 0.0494 - val_within_eps_0_02: 0.0957 - val_within_eps_0_05: 0.2198 - val_within_eps_0_1: 0.3939
# Epoch 27/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0025 - loss: 4.0405e-04 - within_eps_0_005: 0.0742 - within_eps_0_01: 0.1473 - within_eps_0_02: 0.2861 - within_eps_0_05: 0.6092 - within_eps_0_1: 0.8670 - val_log_cosh: 0.0479 - val_loss: 0.0018 - val_within_eps_0_005: 0.0283 - val_within_eps_0_01: 0.0549 - val_within_eps_0_02: 0.1061 - val_within_eps_0_05: 0.2259 - val_within_eps_0_1: 0.4001
# Epoch 28/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - log_cosh: 0.0024 - loss: 3.9706e-04 - within_eps_0_005: 0.0718 - within_eps_0_01: 0.1461 - within_eps_0_02: 0.2863 - within_eps_0_05: 0.6119 - within_eps_0_1: 0.8736 - val_log_cosh: 0.0434 - val_loss: 0.0017 - val_within_eps_0_005: 0.0180 - val_within_eps_0_01: 0.0378 - val_within_eps_0_02: 0.0794 - val_within_eps_0_05: 0.2099 - val_within_eps_0_1: 0.4118
# Epoch 29/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0024 - loss: 4.0064e-04 - within_eps_0_005: 0.0766 - within_eps_0_01: 0.1503 - within_eps_0_02: 0.2898 - within_eps_0_05: 0.6122 - within_eps_0_1: 0.8676 - val_log_cosh: 0.0461 - val_loss: 0.0017 - val_within_eps_0_005: 0.0281 - val_within_eps_0_01: 0.0548 - val_within_eps_0_02: 0.1070 - val_within_eps_0_05: 0.2293 - val_within_eps_0_1: 0.4084
# Epoch 30/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0024 - loss: 3.9554e-04 - within_eps_0_005: 0.0764 - within_eps_0_01: 0.1525 - within_eps_0_02: 0.2921 - within_eps_0_05: 0.6152 - within_eps_0_1: 0.8729 - val_log_cosh: 0.0500 - val_loss: 0.0018 - val_within_eps_0_005: 0.0223 - val_within_eps_0_01: 0.0448 - val_within_eps_0_02: 0.0894 - val_within_eps_0_05: 0.2219 - val_within_eps_0_1: 0.3903
# Epoch 31/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0022 - loss: 3.8272e-04 - within_eps_0_005: 0.0782 - within_eps_0_01: 0.1552 - within_eps_0_02: 0.3008 - within_eps_0_05: 0.6308 - within_eps_0_1: 0.8810 - val_log_cosh: 0.0497 - val_loss: 0.0018 - val_within_eps_0_005: 0.0249 - val_within_eps_0_01: 0.0479 - val_within_eps_0_02: 0.0921 - val_within_eps_0_05: 0.2270 - val_within_eps_0_1: 0.3883
# Epoch 32/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0022 - loss: 3.7941e-04 - within_eps_0_005: 0.0793 - within_eps_0_01: 0.1589 - within_eps_0_02: 0.3036 - within_eps_0_05: 0.6350 - within_eps_0_1: 0.8827 - val_log_cosh: 0.0449 - val_loss: 0.0017 - val_within_eps_0_005: 0.0280 - val_within_eps_0_01: 0.0547 - val_within_eps_0_02: 0.1045 - val_within_eps_0_05: 0.2426 - val_within_eps_0_1: 0.4212
# Epoch 33/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0021 - loss: 3.6980e-04 - within_eps_0_005: 0.0793 - within_eps_0_01: 0.1592 - within_eps_0_02: 0.3080 - within_eps_0_05: 0.6429 - within_eps_0_1: 0.8900 - val_log_cosh: 0.0501 - val_loss: 0.0018 - val_within_eps_0_005: 0.0239 - val_within_eps_0_01: 0.0482 - val_within_eps_0_02: 0.0960 - val_within_eps_0_05: 0.2269 - val_within_eps_0_1: 0.3920
# Epoch 34/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0021 - loss: 3.6766e-04 - within_eps_0_005: 0.0833 - within_eps_0_01: 0.1630 - within_eps_0_02: 0.3121 - within_eps_0_05: 0.6459 - within_eps_0_1: 0.8910 - val_log_cosh: 0.0485 - val_loss: 0.0018 - val_within_eps_0_005: 0.0244 - val_within_eps_0_01: 0.0466 - val_within_eps_0_02: 0.0953 - val_within_eps_0_05: 0.2288 - val_within_eps_0_1: 0.3925
# Epoch 35/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0021 - loss: 3.6398e-04 - within_eps_0_005: 0.0805 - within_eps_0_01: 0.1613 - within_eps_0_02: 0.3152 - within_eps_0_05: 0.6530 - within_eps_0_1: 0.8937 - val_log_cosh: 0.0488 - val_loss: 0.0018 - val_within_eps_0_005: 0.0254 - val_within_eps_0_01: 0.0498 - val_within_eps_0_02: 0.1012 - val_within_eps_0_05: 0.2397 - val_within_eps_0_1: 0.4080
# Epoch 36/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0020 - loss: 3.5210e-04 - within_eps_0_005: 0.0855 - within_eps_0_01: 0.1690 - within_eps_0_02: 0.3269 - within_eps_0_05: 0.6661 - within_eps_0_1: 0.9001 - val_log_cosh: 0.0455 - val_loss: 0.0017 - val_within_eps_0_005: 0.0247 - val_within_eps_0_01: 0.0472 - val_within_eps_0_02: 0.0909 - val_within_eps_0_05: 0.2314 - val_within_eps_0_1: 0.4094
# Epoch 37/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - log_cosh: 0.0019 - loss: 3.5250e-04 - within_eps_0_005: 0.0854 - within_eps_0_01: 0.1712 - within_eps_0_02: 0.3268 - within_eps_0_05: 0.6604 - within_eps_0_1: 0.8992 - val_log_cosh: 0.0478 - val_loss: 0.0018 - val_within_eps_0_005: 0.0243 - val_within_eps_0_01: 0.0496 - val_within_eps_0_02: 0.1027 - val_within_eps_0_05: 0.2428 - val_within_eps_0_1: 0.4099
# Epoch 38/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - log_cosh: 0.0018 - loss: 3.4202e-04 - within_eps_0_005: 0.0885 - within_eps_0_01: 0.1738 - within_eps_0_02: 0.3337 - within_eps_0_05: 0.6711 - within_eps_0_1: 0.9072 - val_log_cosh: 0.0453 - val_loss: 0.0017 - val_within_eps_0_005: 0.0278 - val_within_eps_0_01: 0.0541 - val_within_eps_0_02: 0.1075 - val_within_eps_0_05: 0.2542 - val_within_eps_0_1: 0.4337
# Epoch 39/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0018 - loss: 3.3817e-04 - within_eps_0_005: 0.0878 - within_eps_0_01: 0.1768 - within_eps_0_02: 0.3402 - within_eps_0_05: 0.6793 - within_eps_0_1: 0.9069 - val_log_cosh: 0.0473 - val_loss: 0.0018 - val_within_eps_0_005: 0.0290 - val_within_eps_0_01: 0.0552 - val_within_eps_0_02: 0.1104 - val_within_eps_0_05: 0.2477 - val_within_eps_0_1: 0.4135
# Epoch 40/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - log_cosh: 0.0018 - loss: 3.3681e-04 - within_eps_0_005: 0.0894 - within_eps_0_01: 0.1776 - within_eps_0_02: 0.3380 - within_eps_0_05: 0.6782 - within_eps_0_1: 0.9097 - val_log_cosh: 0.0466 - val_loss: 0.0017 - val_within_eps_0_005: 0.0218 - val_within_eps_0_01: 0.0478 - val_within_eps_0_02: 0.0990 - val_within_eps_0_05: 0.2387 - val_within_eps_0_1: 0.4186
# Epoch 41/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0018 - loss: 3.3498e-04 - within_eps_0_005: 0.0873 - within_eps_0_01: 0.1750 - within_eps_0_02: 0.3379 - within_eps_0_05: 0.6797 - within_eps_0_1: 0.9103 - val_log_cosh: 0.0474 - val_loss: 0.0018 - val_within_eps_0_005: 0.0249 - val_within_eps_0_01: 0.0512 - val_within_eps_0_02: 0.1037 - val_within_eps_0_05: 0.2426 - val_within_eps_0_1: 0.4127
# Epoch 42/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0018 - loss: 3.3205e-04 - within_eps_0_005: 0.0954 - within_eps_0_01: 0.1850 - within_eps_0_02: 0.3465 - within_eps_0_05: 0.6837 - within_eps_0_1: 0.9122 - val_log_cosh: 0.0464 - val_loss: 0.0017 - val_within_eps_0_005: 0.0244 - val_within_eps_0_01: 0.0481 - val_within_eps_0_02: 0.1001 - val_within_eps_0_05: 0.2411 - val_within_eps_0_1: 0.4234
# Epoch 43/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0017 - loss: 3.2613e-04 - within_eps_0_005: 0.0949 - within_eps_0_01: 0.1844 - within_eps_0_02: 0.3516 - within_eps_0_05: 0.6924 - within_eps_0_1: 0.9154 - val_log_cosh: 0.0471 - val_loss: 0.0018 - val_within_eps_0_005: 0.0247 - val_within_eps_0_01: 0.0502 - val_within_eps_0_02: 0.0981 - val_within_eps_0_05: 0.2356 - val_within_eps_0_1: 0.4064
#   -> min val_log_cosh=0.043439649045 | min val_huber=0.001678058179
#
# --- Entrenando δ=0.01 ---
# Epoch 1/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - log_cosh: 0.3245 - loss: 0.0071 - within_eps_0_005: 0.0050 - within_eps_0_01: 0.0099 - within_eps_0_02: 0.0196 - within_eps_0_05: 0.0491 - within_eps_0_1: 0.0979 - val_log_cosh: 0.1643 - val_loss: 0.0046 - val_within_eps_0_005: 0.0090 - val_within_eps_0_01: 0.0186 - val_within_eps_0_02: 0.0390 - val_within_eps_0_05: 0.0936 - val_within_eps_0_1: 0.1724
# Epoch 2/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.1396 - loss: 0.0044 - within_eps_0_005: 0.0072 - within_eps_0_01: 0.0144 - within_eps_0_02: 0.0297 - within_eps_0_05: 0.0717 - within_eps_0_1: 0.1428 - val_log_cosh: 0.1256 - val_loss: 0.0039 - val_within_eps_0_005: 0.0109 - val_within_eps_0_01: 0.0211 - val_within_eps_0_02: 0.0411 - val_within_eps_0_05: 0.1131 - val_within_eps_0_1: 0.2325
# Epoch 3/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.1036 - loss: 0.0037 - within_eps_0_005: 0.0084 - within_eps_0_01: 0.0164 - within_eps_0_02: 0.0339 - within_eps_0_05: 0.0854 - within_eps_0_1: 0.1699 - val_log_cosh: 0.1038 - val_loss: 0.0034 - val_within_eps_0_005: 0.0171 - val_within_eps_0_01: 0.0363 - val_within_eps_0_02: 0.0711 - val_within_eps_0_05: 0.1518 - val_within_eps_0_1: 0.2527
# Epoch 4/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0769 - loss: 0.0032 - within_eps_0_005: 0.0092 - within_eps_0_01: 0.0191 - within_eps_0_02: 0.0393 - within_eps_0_05: 0.0986 - within_eps_0_1: 0.1991 - val_log_cosh: 0.0908 - val_loss: 0.0032 - val_within_eps_0_005: 0.0139 - val_within_eps_0_01: 0.0260 - val_within_eps_0_02: 0.0504 - val_within_eps_0_05: 0.1156 - val_within_eps_0_1: 0.2339
# Epoch 5/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - log_cosh: 0.0546 - loss: 0.0026 - within_eps_0_005: 0.0126 - within_eps_0_01: 0.0255 - within_eps_0_02: 0.0505 - within_eps_0_05: 0.1234 - within_eps_0_1: 0.2410 - val_log_cosh: 0.0823 - val_loss: 0.0030 - val_within_eps_0_005: 0.0115 - val_within_eps_0_01: 0.0247 - val_within_eps_0_02: 0.0484 - val_within_eps_0_05: 0.1122 - val_within_eps_0_1: 0.2268
# Epoch 6/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0371 - loss: 0.0021 - within_eps_0_005: 0.0156 - within_eps_0_01: 0.0308 - within_eps_0_02: 0.0613 - within_eps_0_05: 0.1524 - within_eps_0_1: 0.2963 - val_log_cosh: 0.0758 - val_loss: 0.0029 - val_within_eps_0_005: 0.0118 - val_within_eps_0_01: 0.0224 - val_within_eps_0_02: 0.0446 - val_within_eps_0_05: 0.1215 - val_within_eps_0_1: 0.2421
# Epoch 7/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0258 - loss: 0.0017 - within_eps_0_005: 0.0184 - within_eps_0_01: 0.0366 - within_eps_0_02: 0.0737 - within_eps_0_05: 0.1850 - within_eps_0_1: 0.3597 - val_log_cosh: 0.0713 - val_loss: 0.0028 - val_within_eps_0_005: 0.0107 - val_within_eps_0_01: 0.0227 - val_within_eps_0_02: 0.0478 - val_within_eps_0_05: 0.1206 - val_within_eps_0_1: 0.2625
# Epoch 8/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - log_cosh: 0.0169 - loss: 0.0014 - within_eps_0_005: 0.0236 - within_eps_0_01: 0.0471 - within_eps_0_02: 0.0929 - within_eps_0_05: 0.2303 - within_eps_0_1: 0.4415 - val_log_cosh: 0.0657 - val_loss: 0.0026 - val_within_eps_0_005: 0.0116 - val_within_eps_0_01: 0.0235 - val_within_eps_0_02: 0.0477 - val_within_eps_0_05: 0.1383 - val_within_eps_0_1: 0.2891
# Epoch 9/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0120 - loss: 0.0012 - within_eps_0_005: 0.0286 - within_eps_0_01: 0.0563 - within_eps_0_02: 0.1134 - within_eps_0_05: 0.2762 - within_eps_0_1: 0.5147 - val_log_cosh: 0.0675 - val_loss: 0.0026 - val_within_eps_0_005: 0.0156 - val_within_eps_0_01: 0.0335 - val_within_eps_0_02: 0.0658 - val_within_eps_0_05: 0.1649 - val_within_eps_0_1: 0.3121
# Epoch 10/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0087 - loss: 9.6629e-04 - within_eps_0_005: 0.0337 - within_eps_0_01: 0.0679 - within_eps_0_02: 0.1355 - within_eps_0_05: 0.3307 - within_eps_0_1: 0.5935 - val_log_cosh: 0.0628 - val_loss: 0.0025 - val_within_eps_0_005: 0.0182 - val_within_eps_0_01: 0.0356 - val_within_eps_0_02: 0.0684 - val_within_eps_0_05: 0.1769 - val_within_eps_0_1: 0.3257
# Epoch 11/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - log_cosh: 0.0069 - loss: 8.5007e-04 - within_eps_0_005: 0.0411 - within_eps_0_01: 0.0808 - within_eps_0_02: 0.1562 - within_eps_0_05: 0.3702 - within_eps_0_1: 0.6497 - val_log_cosh: 0.0662 - val_loss: 0.0026 - val_within_eps_0_005: 0.0206 - val_within_eps_0_01: 0.0428 - val_within_eps_0_02: 0.0822 - val_within_eps_0_05: 0.1851 - val_within_eps_0_1: 0.3338
# Epoch 12/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - log_cosh: 0.0058 - loss: 7.7194e-04 - within_eps_0_005: 0.0446 - within_eps_0_01: 0.0869 - within_eps_0_02: 0.1715 - within_eps_0_05: 0.4038 - within_eps_0_1: 0.6915 - val_log_cosh: 0.0696 - val_loss: 0.0027 - val_within_eps_0_005: 0.0155 - val_within_eps_0_01: 0.0340 - val_within_eps_0_02: 0.0721 - val_within_eps_0_05: 0.1694 - val_within_eps_0_1: 0.3203
# Epoch 13/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - log_cosh: 0.0052 - loss: 7.2454e-04 - within_eps_0_005: 0.0452 - within_eps_0_01: 0.0905 - within_eps_0_02: 0.1809 - within_eps_0_05: 0.4277 - within_eps_0_1: 0.7177 - val_log_cosh: 0.0593 - val_loss: 0.0024 - val_within_eps_0_005: 0.0224 - val_within_eps_0_01: 0.0444 - val_within_eps_0_02: 0.0874 - val_within_eps_0_05: 0.2082 - val_within_eps_0_1: 0.3557
# Epoch 14/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - log_cosh: 0.0048 - loss: 6.9307e-04 - within_eps_0_005: 0.0483 - within_eps_0_01: 0.0965 - within_eps_0_02: 0.1897 - within_eps_0_05: 0.4443 - within_eps_0_1: 0.7367 - val_log_cosh: 0.0552 - val_loss: 0.0023 - val_within_eps_0_005: 0.0228 - val_within_eps_0_01: 0.0426 - val_within_eps_0_02: 0.0871 - val_within_eps_0_05: 0.2155 - val_within_eps_0_1: 0.3718
# Epoch 15/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - log_cosh: 0.0046 - loss: 6.7417e-04 - within_eps_0_005: 0.0501 - within_eps_0_01: 0.1001 - within_eps_0_02: 0.1964 - within_eps_0_05: 0.4554 - within_eps_0_1: 0.7497 - val_log_cosh: 0.0617 - val_loss: 0.0025 - val_within_eps_0_005: 0.0208 - val_within_eps_0_01: 0.0433 - val_within_eps_0_02: 0.0849 - val_within_eps_0_05: 0.2008 - val_within_eps_0_1: 0.3482
# Epoch 16/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0042 - loss: 6.4329e-04 - within_eps_0_005: 0.0511 - within_eps_0_01: 0.1030 - within_eps_0_02: 0.2041 - within_eps_0_05: 0.4738 - within_eps_0_1: 0.7648 - val_log_cosh: 0.0520 - val_loss: 0.0022 - val_within_eps_0_005: 0.0220 - val_within_eps_0_01: 0.0450 - val_within_eps_0_02: 0.0863 - val_within_eps_0_05: 0.2056 - val_within_eps_0_1: 0.3663
# Epoch 17/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0040 - loss: 6.2760e-04 - within_eps_0_005: 0.0556 - within_eps_0_01: 0.1070 - within_eps_0_02: 0.2110 - within_eps_0_05: 0.4845 - within_eps_0_1: 0.7772 - val_log_cosh: 0.0515 - val_loss: 0.0022 - val_within_eps_0_005: 0.0215 - val_within_eps_0_01: 0.0427 - val_within_eps_0_02: 0.0815 - val_within_eps_0_05: 0.2001 - val_within_eps_0_1: 0.3717
# Epoch 18/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0037 - loss: 6.0002e-04 - within_eps_0_005: 0.0565 - within_eps_0_01: 0.1095 - within_eps_0_02: 0.2175 - within_eps_0_05: 0.5022 - within_eps_0_1: 0.7917 - val_log_cosh: 0.0513 - val_loss: 0.0022 - val_within_eps_0_005: 0.0232 - val_within_eps_0_01: 0.0470 - val_within_eps_0_02: 0.0951 - val_within_eps_0_05: 0.2160 - val_within_eps_0_1: 0.3777
# Epoch 19/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0035 - loss: 5.8325e-04 - within_eps_0_005: 0.0569 - within_eps_0_01: 0.1121 - within_eps_0_02: 0.2224 - within_eps_0_05: 0.5136 - within_eps_0_1: 0.8022 - val_log_cosh: 0.0508 - val_loss: 0.0022 - val_within_eps_0_005: 0.0222 - val_within_eps_0_01: 0.0453 - val_within_eps_0_02: 0.0883 - val_within_eps_0_05: 0.2172 - val_within_eps_0_1: 0.3828
# Epoch 20/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0034 - loss: 5.6338e-04 - within_eps_0_005: 0.0598 - within_eps_0_01: 0.1200 - within_eps_0_02: 0.2335 - within_eps_0_05: 0.5283 - within_eps_0_1: 0.8134 - val_log_cosh: 0.0538 - val_loss: 0.0023 - val_within_eps_0_005: 0.0190 - val_within_eps_0_01: 0.0364 - val_within_eps_0_02: 0.0774 - val_within_eps_0_05: 0.1967 - val_within_eps_0_1: 0.3606
# Epoch 21/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0032 - loss: 5.4931e-04 - within_eps_0_005: 0.0592 - within_eps_0_01: 0.1190 - within_eps_0_02: 0.2381 - within_eps_0_05: 0.5352 - within_eps_0_1: 0.8236 - val_log_cosh: 0.0437 - val_loss: 0.0020 - val_within_eps_0_005: 0.0277 - val_within_eps_0_01: 0.0550 - val_within_eps_0_02: 0.1063 - val_within_eps_0_05: 0.2413 - val_within_eps_0_1: 0.4089
# Epoch 22/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0030 - loss: 5.3045e-04 - within_eps_0_005: 0.0632 - within_eps_0_01: 0.1244 - within_eps_0_02: 0.2481 - within_eps_0_05: 0.5503 - within_eps_0_1: 0.8329 - val_log_cosh: 0.0494 - val_loss: 0.0022 - val_within_eps_0_005: 0.0245 - val_within_eps_0_01: 0.0488 - val_within_eps_0_02: 0.0968 - val_within_eps_0_05: 0.2114 - val_within_eps_0_1: 0.3754
# Epoch 23/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - log_cosh: 0.0031 - loss: 5.3708e-04 - within_eps_0_005: 0.0627 - within_eps_0_01: 0.1247 - within_eps_0_02: 0.2462 - within_eps_0_05: 0.5504 - within_eps_0_1: 0.8320 - val_log_cosh: 0.0451 - val_loss: 0.0020 - val_within_eps_0_005: 0.0286 - val_within_eps_0_01: 0.0576 - val_within_eps_0_02: 0.1054 - val_within_eps_0_05: 0.2369 - val_within_eps_0_1: 0.4031
# Epoch 24/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0029 - loss: 5.1645e-04 - within_eps_0_005: 0.0646 - within_eps_0_01: 0.1304 - within_eps_0_02: 0.2553 - within_eps_0_05: 0.5618 - within_eps_0_1: 0.8408 - val_log_cosh: 0.0493 - val_loss: 0.0021 - val_within_eps_0_005: 0.0229 - val_within_eps_0_01: 0.0473 - val_within_eps_0_02: 0.0971 - val_within_eps_0_05: 0.2331 - val_within_eps_0_1: 0.3964
# Epoch 25/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0027 - loss: 4.9765e-04 - within_eps_0_005: 0.0658 - within_eps_0_01: 0.1318 - within_eps_0_02: 0.2605 - within_eps_0_05: 0.5750 - within_eps_0_1: 0.8509 - val_log_cosh: 0.0466 - val_loss: 0.0021 - val_within_eps_0_005: 0.0264 - val_within_eps_0_01: 0.0510 - val_within_eps_0_02: 0.0986 - val_within_eps_0_05: 0.2349 - val_within_eps_0_1: 0.4042
# Epoch 26/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - log_cosh: 0.0027 - loss: 4.9455e-04 - within_eps_0_005: 0.0692 - within_eps_0_01: 0.1350 - within_eps_0_02: 0.2652 - within_eps_0_05: 0.5817 - within_eps_0_1: 0.8543 - val_log_cosh: 0.0517 - val_loss: 0.0022 - val_within_eps_0_005: 0.0225 - val_within_eps_0_01: 0.0460 - val_within_eps_0_02: 0.0945 - val_within_eps_0_05: 0.2141 - val_within_eps_0_1: 0.3692
# Epoch 27/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - log_cosh: 0.0025 - loss: 4.7595e-04 - within_eps_0_005: 0.0703 - within_eps_0_01: 0.1405 - within_eps_0_02: 0.2765 - within_eps_0_05: 0.5982 - within_eps_0_1: 0.8653 - val_log_cosh: 0.0518 - val_loss: 0.0022 - val_within_eps_0_005: 0.0262 - val_within_eps_0_01: 0.0491 - val_within_eps_0_02: 0.0949 - val_within_eps_0_05: 0.2130 - val_within_eps_0_1: 0.3751
# Epoch 28/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0024 - loss: 4.7072e-04 - within_eps_0_005: 0.0729 - within_eps_0_01: 0.1409 - within_eps_0_02: 0.2772 - within_eps_0_05: 0.5994 - within_eps_0_1: 0.8673 - val_log_cosh: 0.0504 - val_loss: 0.0022 - val_within_eps_0_005: 0.0246 - val_within_eps_0_01: 0.0498 - val_within_eps_0_02: 0.0944 - val_within_eps_0_05: 0.2136 - val_within_eps_0_1: 0.3697
# Epoch 29/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0023 - loss: 4.5689e-04 - within_eps_0_005: 0.0730 - within_eps_0_01: 0.1455 - within_eps_0_02: 0.2841 - within_eps_0_05: 0.6113 - within_eps_0_1: 0.8772 - val_log_cosh: 0.0496 - val_loss: 0.0022 - val_within_eps_0_005: 0.0239 - val_within_eps_0_01: 0.0487 - val_within_eps_0_02: 0.0957 - val_within_eps_0_05: 0.2177 - val_within_eps_0_1: 0.3840
# Epoch 30/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - log_cosh: 0.0023 - loss: 4.5186e-04 - within_eps_0_005: 0.0757 - within_eps_0_01: 0.1486 - within_eps_0_02: 0.2884 - within_eps_0_05: 0.6179 - within_eps_0_1: 0.8779 - val_log_cosh: 0.0493 - val_loss: 0.0021 - val_within_eps_0_005: 0.0243 - val_within_eps_0_01: 0.0482 - val_within_eps_0_02: 0.0926 - val_within_eps_0_05: 0.2191 - val_within_eps_0_1: 0.3933
# Epoch 31/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0022 - loss: 4.4493e-04 - within_eps_0_005: 0.0755 - within_eps_0_01: 0.1515 - within_eps_0_02: 0.2935 - within_eps_0_05: 0.6273 - within_eps_0_1: 0.8799 - val_log_cosh: 0.0498 - val_loss: 0.0022 - val_within_eps_0_005: 0.0232 - val_within_eps_0_01: 0.0468 - val_within_eps_0_02: 0.0940 - val_within_eps_0_05: 0.2209 - val_within_eps_0_1: 0.3922
# Epoch 32/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0022 - loss: 4.3512e-04 - within_eps_0_005: 0.0770 - within_eps_0_01: 0.1529 - within_eps_0_02: 0.2996 - within_eps_0_05: 0.6333 - within_eps_0_1: 0.8872 - val_log_cosh: 0.0482 - val_loss: 0.0021 - val_within_eps_0_005: 0.0213 - val_within_eps_0_01: 0.0422 - val_within_eps_0_02: 0.0870 - val_within_eps_0_05: 0.2263 - val_within_eps_0_1: 0.4026
# Epoch 33/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - log_cosh: 0.0021 - loss: 4.2918e-04 - within_eps_0_005: 0.0809 - within_eps_0_01: 0.1598 - within_eps_0_02: 0.3059 - within_eps_0_05: 0.6393 - within_eps_0_1: 0.8885 - val_log_cosh: 0.0490 - val_loss: 0.0021 - val_within_eps_0_005: 0.0207 - val_within_eps_0_01: 0.0433 - val_within_eps_0_02: 0.0885 - val_within_eps_0_05: 0.2215 - val_within_eps_0_1: 0.3892
# Epoch 34/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0021 - loss: 4.1990e-04 - within_eps_0_005: 0.0833 - within_eps_0_01: 0.1630 - within_eps_0_02: 0.3139 - within_eps_0_05: 0.6478 - within_eps_0_1: 0.8937 - val_log_cosh: 0.0512 - val_loss: 0.0022 - val_within_eps_0_005: 0.0218 - val_within_eps_0_01: 0.0448 - val_within_eps_0_02: 0.0887 - val_within_eps_0_05: 0.2177 - val_within_eps_0_1: 0.3862
# Epoch 35/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - log_cosh: 0.0019 - loss: 4.1145e-04 - within_eps_0_005: 0.0842 - within_eps_0_01: 0.1637 - within_eps_0_02: 0.3148 - within_eps_0_05: 0.6541 - within_eps_0_1: 0.8990 - val_log_cosh: 0.0487 - val_loss: 0.0021 - val_within_eps_0_005: 0.0220 - val_within_eps_0_01: 0.0451 - val_within_eps_0_02: 0.0918 - val_within_eps_0_05: 0.2244 - val_within_eps_0_1: 0.3890
# Epoch 36/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0020 - loss: 4.1606e-04 - within_eps_0_005: 0.0822 - within_eps_0_01: 0.1622 - within_eps_0_02: 0.3094 - within_eps_0_05: 0.6503 - within_eps_0_1: 0.8976 - val_log_cosh: 0.0505 - val_loss: 0.0022 - val_within_eps_0_005: 0.0240 - val_within_eps_0_01: 0.0477 - val_within_eps_0_02: 0.0959 - val_within_eps_0_05: 0.2270 - val_within_eps_0_1: 0.3911
#   -> min val_log_cosh=0.043743524700 | min val_huber=0.001997717656
#
# --- Entrenando δ=0.017357412725687027 ---
# Epoch 1/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - log_cosh: 0.3044 - loss: 0.0118 - within_eps_0_005: 0.0049 - within_eps_0_01: 0.0101 - within_eps_0_02: 0.0199 - within_eps_0_05: 0.0502 - within_eps_0_1: 0.0992 - val_log_cosh: 0.1274 - val_loss: 0.0071 - val_within_eps_0_005: 0.0057 - val_within_eps_0_01: 0.0110 - val_within_eps_0_02: 0.0210 - val_within_eps_0_05: 0.0609 - val_within_eps_0_1: 0.1406
# Epoch 2/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.1314 - loss: 0.0073 - within_eps_0_005: 0.0076 - within_eps_0_01: 0.0149 - within_eps_0_02: 0.0298 - within_eps_0_05: 0.0753 - within_eps_0_1: 0.1465 - val_log_cosh: 0.0967 - val_loss: 0.0059 - val_within_eps_0_005: 0.0076 - val_within_eps_0_01: 0.0159 - val_within_eps_0_02: 0.0311 - val_within_eps_0_05: 0.0762 - val_within_eps_0_1: 0.1794
# Epoch 3/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0946 - loss: 0.0061 - within_eps_0_005: 0.0081 - within_eps_0_01: 0.0170 - within_eps_0_02: 0.0334 - within_eps_0_05: 0.0879 - within_eps_0_1: 0.1769 - val_log_cosh: 0.0746 - val_loss: 0.0050 - val_within_eps_0_005: 0.0120 - val_within_eps_0_01: 0.0244 - val_within_eps_0_02: 0.0491 - val_within_eps_0_05: 0.1202 - val_within_eps_0_1: 0.2404
# Epoch 4/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0697 - loss: 0.0052 - within_eps_0_005: 0.0115 - within_eps_0_01: 0.0215 - within_eps_0_02: 0.0422 - within_eps_0_05: 0.1071 - within_eps_0_1: 0.2105 - val_log_cosh: 0.0685 - val_loss: 0.0047 - val_within_eps_0_005: 0.0136 - val_within_eps_0_01: 0.0290 - val_within_eps_0_02: 0.0607 - val_within_eps_0_05: 0.1484 - val_within_eps_0_1: 0.2644
# Epoch 5/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0496 - loss: 0.0043 - within_eps_0_005: 0.0130 - within_eps_0_01: 0.0258 - within_eps_0_02: 0.0512 - within_eps_0_05: 0.1284 - within_eps_0_1: 0.2523 - val_log_cosh: 0.0660 - val_loss: 0.0046 - val_within_eps_0_005: 0.0166 - val_within_eps_0_01: 0.0311 - val_within_eps_0_02: 0.0623 - val_within_eps_0_05: 0.1443 - val_within_eps_0_1: 0.2697
# Epoch 6/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - log_cosh: 0.0340 - loss: 0.0035 - within_eps_0_005: 0.0158 - within_eps_0_01: 0.0324 - within_eps_0_02: 0.0642 - within_eps_0_05: 0.1573 - within_eps_0_1: 0.3064 - val_log_cosh: 0.0596 - val_loss: 0.0043 - val_within_eps_0_005: 0.0147 - val_within_eps_0_01: 0.0285 - val_within_eps_0_02: 0.0563 - val_within_eps_0_05: 0.1504 - val_within_eps_0_1: 0.2961
# Epoch 7/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - log_cosh: 0.0227 - loss: 0.0028 - within_eps_0_005: 0.0200 - within_eps_0_01: 0.0398 - within_eps_0_02: 0.0797 - within_eps_0_05: 0.1959 - within_eps_0_1: 0.3791 - val_log_cosh: 0.0648 - val_loss: 0.0045 - val_within_eps_0_005: 0.0161 - val_within_eps_0_01: 0.0343 - val_within_eps_0_02: 0.0684 - val_within_eps_0_05: 0.1536 - val_within_eps_0_1: 0.2844
# Epoch 8/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - log_cosh: 0.0149 - loss: 0.0022 - within_eps_0_005: 0.0245 - within_eps_0_01: 0.0486 - within_eps_0_02: 0.0980 - within_eps_0_05: 0.2417 - within_eps_0_1: 0.4628 - val_log_cosh: 0.0545 - val_loss: 0.0040 - val_within_eps_0_005: 0.0223 - val_within_eps_0_01: 0.0414 - val_within_eps_0_02: 0.0826 - val_within_eps_0_05: 0.1791 - val_within_eps_0_1: 0.3180
# Epoch 9/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0099 - loss: 0.0018 - within_eps_0_005: 0.0304 - within_eps_0_01: 0.0603 - within_eps_0_02: 0.1222 - within_eps_0_05: 0.3012 - within_eps_0_1: 0.5563 - val_log_cosh: 0.0519 - val_loss: 0.0040 - val_within_eps_0_005: 0.0164 - val_within_eps_0_01: 0.0335 - val_within_eps_0_02: 0.0665 - val_within_eps_0_05: 0.1630 - val_within_eps_0_1: 0.3211
# Epoch 10/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - log_cosh: 0.0076 - loss: 0.0015 - within_eps_0_005: 0.0361 - within_eps_0_01: 0.0727 - within_eps_0_02: 0.1451 - within_eps_0_05: 0.3507 - within_eps_0_1: 0.6256 - val_log_cosh: 0.0507 - val_loss: 0.0039 - val_within_eps_0_005: 0.0195 - val_within_eps_0_01: 0.0385 - val_within_eps_0_02: 0.0802 - val_within_eps_0_05: 0.1888 - val_within_eps_0_1: 0.3461
# Epoch 11/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0061 - loss: 0.0013 - within_eps_0_005: 0.0412 - within_eps_0_01: 0.0820 - within_eps_0_02: 0.1657 - within_eps_0_05: 0.3914 - within_eps_0_1: 0.6764 - val_log_cosh: 0.0555 - val_loss: 0.0042 - val_within_eps_0_005: 0.0195 - val_within_eps_0_01: 0.0373 - val_within_eps_0_02: 0.0727 - val_within_eps_0_05: 0.1657 - val_within_eps_0_1: 0.3097
# Epoch 12/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0053 - loss: 0.0012 - within_eps_0_005: 0.0441 - within_eps_0_01: 0.0893 - within_eps_0_02: 0.1778 - within_eps_0_05: 0.4217 - within_eps_0_1: 0.7096 - val_log_cosh: 0.0516 - val_loss: 0.0040 - val_within_eps_0_005: 0.0193 - val_within_eps_0_01: 0.0392 - val_within_eps_0_02: 0.0811 - val_within_eps_0_05: 0.1872 - val_within_eps_0_1: 0.3354
# Epoch 13/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0047 - loss: 0.0011 - within_eps_0_005: 0.0476 - within_eps_0_01: 0.0935 - within_eps_0_02: 0.1861 - within_eps_0_05: 0.4405 - within_eps_0_1: 0.7348 - val_log_cosh: 0.0483 - val_loss: 0.0039 - val_within_eps_0_005: 0.0176 - val_within_eps_0_01: 0.0342 - val_within_eps_0_02: 0.0660 - val_within_eps_0_05: 0.1804 - val_within_eps_0_1: 0.3420
# Epoch 14/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0044 - loss: 0.0011 - within_eps_0_005: 0.0512 - within_eps_0_01: 0.1019 - within_eps_0_02: 0.1991 - within_eps_0_05: 0.4608 - within_eps_0_1: 0.7547 - val_log_cosh: 0.0435 - val_loss: 0.0036 - val_within_eps_0_005: 0.0185 - val_within_eps_0_01: 0.0349 - val_within_eps_0_02: 0.0734 - val_within_eps_0_05: 0.1867 - val_within_eps_0_1: 0.3444
# Epoch 15/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0040 - loss: 0.0010 - within_eps_0_005: 0.0526 - within_eps_0_01: 0.1053 - within_eps_0_02: 0.2094 - within_eps_0_05: 0.4847 - within_eps_0_1: 0.7746 - val_log_cosh: 0.0477 - val_loss: 0.0038 - val_within_eps_0_005: 0.0196 - val_within_eps_0_01: 0.0377 - val_within_eps_0_02: 0.0759 - val_within_eps_0_05: 0.1860 - val_within_eps_0_1: 0.3413
# Epoch 16/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0039 - loss: 0.0010 - within_eps_0_005: 0.0537 - within_eps_0_01: 0.1084 - within_eps_0_02: 0.2133 - within_eps_0_05: 0.4931 - within_eps_0_1: 0.7796 - val_log_cosh: 0.0442 - val_loss: 0.0036 - val_within_eps_0_005: 0.0189 - val_within_eps_0_01: 0.0375 - val_within_eps_0_02: 0.0761 - val_within_eps_0_05: 0.1934 - val_within_eps_0_1: 0.3681
# Epoch 17/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - log_cosh: 0.0036 - loss: 9.6555e-04 - within_eps_0_005: 0.0555 - within_eps_0_01: 0.1115 - within_eps_0_02: 0.2227 - within_eps_0_05: 0.5098 - within_eps_0_1: 0.7994 - val_log_cosh: 0.0444 - val_loss: 0.0037 - val_within_eps_0_005: 0.0167 - val_within_eps_0_01: 0.0360 - val_within_eps_0_02: 0.0726 - val_within_eps_0_05: 0.1793 - val_within_eps_0_1: 0.3464
# Epoch 18/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.0034 - loss: 9.3347e-04 - within_eps_0_005: 0.0598 - within_eps_0_01: 0.1172 - within_eps_0_02: 0.2316 - within_eps_0_05: 0.5221 - within_eps_0_1: 0.8083 - val_log_cosh: 0.0419 - val_loss: 0.0035 - val_within_eps_0_005: 0.0175 - val_within_eps_0_01: 0.0351 - val_within_eps_0_02: 0.0766 - val_within_eps_0_05: 0.2080 - val_within_eps_0_1: 0.3770
# Epoch 19/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.0033 - loss: 9.1962e-04 - within_eps_0_005: 0.0587 - within_eps_0_01: 0.1190 - within_eps_0_02: 0.2326 - within_eps_0_05: 0.5299 - within_eps_0_1: 0.8120 - val_log_cosh: 0.0400 - val_loss: 0.0034 - val_within_eps_0_005: 0.0231 - val_within_eps_0_01: 0.0455 - val_within_eps_0_02: 0.0880 - val_within_eps_0_05: 0.2067 - val_within_eps_0_1: 0.3731
# Epoch 20/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0032 - loss: 8.8620e-04 - within_eps_0_005: 0.0653 - within_eps_0_01: 0.1270 - within_eps_0_02: 0.2445 - within_eps_0_05: 0.5431 - within_eps_0_1: 0.8241 - val_log_cosh: 0.0440 - val_loss: 0.0036 - val_within_eps_0_005: 0.0221 - val_within_eps_0_01: 0.0410 - val_within_eps_0_02: 0.0812 - val_within_eps_0_05: 0.1952 - val_within_eps_0_1: 0.3698
# Epoch 21/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0030 - loss: 8.6415e-04 - within_eps_0_005: 0.0644 - within_eps_0_01: 0.1277 - within_eps_0_02: 0.2490 - within_eps_0_05: 0.5519 - within_eps_0_1: 0.8311 - val_log_cosh: 0.0413 - val_loss: 0.0034 - val_within_eps_0_005: 0.0239 - val_within_eps_0_01: 0.0476 - val_within_eps_0_02: 0.0930 - val_within_eps_0_05: 0.2136 - val_within_eps_0_1: 0.3859
# Epoch 22/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0030 - loss: 8.5042e-04 - within_eps_0_005: 0.0652 - within_eps_0_01: 0.1297 - within_eps_0_02: 0.2538 - within_eps_0_05: 0.5634 - within_eps_0_1: 0.8350 - val_log_cosh: 0.0418 - val_loss: 0.0035 - val_within_eps_0_005: 0.0240 - val_within_eps_0_01: 0.0473 - val_within_eps_0_02: 0.0906 - val_within_eps_0_05: 0.2113 - val_within_eps_0_1: 0.3883
# Epoch 23/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - log_cosh: 0.0027 - loss: 8.1885e-04 - within_eps_0_005: 0.0675 - within_eps_0_01: 0.1313 - within_eps_0_02: 0.2597 - within_eps_0_05: 0.5733 - within_eps_0_1: 0.8463 - val_log_cosh: 0.0416 - val_loss: 0.0034 - val_within_eps_0_005: 0.0238 - val_within_eps_0_01: 0.0476 - val_within_eps_0_02: 0.0925 - val_within_eps_0_05: 0.2154 - val_within_eps_0_1: 0.3923
# Epoch 24/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0026 - loss: 7.9628e-04 - within_eps_0_005: 0.0694 - within_eps_0_01: 0.1400 - within_eps_0_02: 0.2682 - within_eps_0_05: 0.5838 - within_eps_0_1: 0.8543 - val_log_cosh: 0.0435 - val_loss: 0.0036 - val_within_eps_0_005: 0.0182 - val_within_eps_0_01: 0.0363 - val_within_eps_0_02: 0.0756 - val_within_eps_0_05: 0.1974 - val_within_eps_0_1: 0.3769
# Epoch 25/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0027 - loss: 8.0362e-04 - within_eps_0_005: 0.0687 - within_eps_0_01: 0.1361 - within_eps_0_02: 0.2657 - within_eps_0_05: 0.5829 - within_eps_0_1: 0.8525 - val_log_cosh: 0.0411 - val_loss: 0.0034 - val_within_eps_0_005: 0.0227 - val_within_eps_0_01: 0.0453 - val_within_eps_0_02: 0.0914 - val_within_eps_0_05: 0.2188 - val_within_eps_0_1: 0.3921
# Epoch 26/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.0024 - loss: 7.5397e-04 - within_eps_0_005: 0.0711 - within_eps_0_01: 0.1431 - within_eps_0_02: 0.2795 - within_eps_0_05: 0.6055 - within_eps_0_1: 0.8687 - val_log_cosh: 0.0425 - val_loss: 0.0035 - val_within_eps_0_005: 0.0220 - val_within_eps_0_01: 0.0444 - val_within_eps_0_02: 0.0897 - val_within_eps_0_05: 0.2106 - val_within_eps_0_1: 0.3765
# Epoch 27/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0024 - loss: 7.5827e-04 - within_eps_0_005: 0.0724 - within_eps_0_01: 0.1429 - within_eps_0_02: 0.2786 - within_eps_0_05: 0.6040 - within_eps_0_1: 0.8665 - val_log_cosh: 0.0414 - val_loss: 0.0034 - val_within_eps_0_005: 0.0270 - val_within_eps_0_01: 0.0511 - val_within_eps_0_02: 0.0959 - val_within_eps_0_05: 0.2196 - val_within_eps_0_1: 0.3827
# Epoch 28/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0023 - loss: 7.3846e-04 - within_eps_0_005: 0.0735 - within_eps_0_01: 0.1454 - within_eps_0_02: 0.2875 - within_eps_0_05: 0.6121 - within_eps_0_1: 0.8749 - val_log_cosh: 0.0427 - val_loss: 0.0034 - val_within_eps_0_005: 0.0212 - val_within_eps_0_01: 0.0431 - val_within_eps_0_02: 0.0889 - val_within_eps_0_05: 0.2229 - val_within_eps_0_1: 0.3995
# Epoch 29/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.0024 - loss: 7.3655e-04 - within_eps_0_005: 0.0733 - within_eps_0_01: 0.1469 - within_eps_0_02: 0.2893 - within_eps_0_05: 0.6196 - within_eps_0_1: 0.8742 - val_log_cosh: 0.0400 - val_loss: 0.0033 - val_within_eps_0_005: 0.0237 - val_within_eps_0_01: 0.0493 - val_within_eps_0_02: 0.0943 - val_within_eps_0_05: 0.2315 - val_within_eps_0_1: 0.4056
# Epoch 30/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0021 - loss: 6.8811e-04 - within_eps_0_005: 0.0787 - within_eps_0_01: 0.1552 - within_eps_0_02: 0.3022 - within_eps_0_05: 0.6392 - within_eps_0_1: 0.8919 - val_log_cosh: 0.0432 - val_loss: 0.0035 - val_within_eps_0_005: 0.0216 - val_within_eps_0_01: 0.0456 - val_within_eps_0_02: 0.0898 - val_within_eps_0_05: 0.2229 - val_within_eps_0_1: 0.3930
# Epoch 31/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0022 - loss: 7.0130e-04 - within_eps_0_005: 0.0770 - within_eps_0_01: 0.1525 - within_eps_0_02: 0.2994 - within_eps_0_05: 0.6339 - within_eps_0_1: 0.8859 - val_log_cosh: 0.0384 - val_loss: 0.0032 - val_within_eps_0_005: 0.0281 - val_within_eps_0_01: 0.0568 - val_within_eps_0_02: 0.1099 - val_within_eps_0_05: 0.2425 - val_within_eps_0_1: 0.4250
# Epoch 32/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.0021 - loss: 6.8430e-04 - within_eps_0_005: 0.0809 - within_eps_0_01: 0.1652 - within_eps_0_02: 0.3128 - within_eps_0_05: 0.6424 - within_eps_0_1: 0.8891 - val_log_cosh: 0.0469 - val_loss: 0.0036 - val_within_eps_0_005: 0.0220 - val_within_eps_0_01: 0.0453 - val_within_eps_0_02: 0.0901 - val_within_eps_0_05: 0.2185 - val_within_eps_0_1: 0.3866
# Epoch 33/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - log_cosh: 0.0020 - loss: 6.6488e-04 - within_eps_0_005: 0.0803 - within_eps_0_01: 0.1615 - within_eps_0_02: 0.3131 - within_eps_0_05: 0.6535 - within_eps_0_1: 0.8985 - val_log_cosh: 0.0469 - val_loss: 0.0037 - val_within_eps_0_005: 0.0211 - val_within_eps_0_01: 0.0434 - val_within_eps_0_02: 0.0862 - val_within_eps_0_05: 0.2094 - val_within_eps_0_1: 0.3710
# Epoch 34/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - log_cosh: 0.0020 - loss: 6.6150e-04 - within_eps_0_005: 0.0826 - within_eps_0_01: 0.1637 - within_eps_0_02: 0.3177 - within_eps_0_05: 0.6612 - within_eps_0_1: 0.8992 - val_log_cosh: 0.0450 - val_loss: 0.0036 - val_within_eps_0_005: 0.0191 - val_within_eps_0_01: 0.0400 - val_within_eps_0_02: 0.0801 - val_within_eps_0_05: 0.2137 - val_within_eps_0_1: 0.3800
# Epoch 35/160
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - log_cosh: 0.0019 - loss: 6.5024e-04 - within_eps_0_005: 0.0840 - within_eps_0_01: 0.1652 - within_eps_0_02: 0.3214 - within_eps_0_05: 0.6611 - within_eps_0_1: 0.8997 - val_log_cosh: 0.0520 - val_loss: 0.0039 - val_within_eps_0_005: 0.0195 - val_within_eps_0_01: 0.0384 - val_within_eps_0_02: 0.0758 - val_within_eps_0_05: 0.1789 - val_within_eps_0_1: 0.3437
# Epoch 36/160
# ...
# Epoch 20/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - log_cosh: 0.0026 - loss: 0.0023 - within_eps_0_005: 0.0680 - within_eps_0_01: 0.1361 - within_eps_0_02: 0.2658 - within_eps_0_05: 0.5841 - within_eps_0_1: 0.8593 - val_log_cosh: 0.0666 - val_loss: 0.0220 - val_within_eps_0_005: 0.0154 - val_within_eps_0_01: 0.0305 - val_within_eps_0_02: 0.0607 - val_within_eps_0_05: 0.1513 - val_within_eps_0_1: 0.2904
# Epoch 21/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - log_cosh: 0.0025 - loss: 0.0023 - within_eps_0_005: 0.0684 - within_eps_0_01: 0.1361 - within_eps_0_02: 0.2666 - within_eps_0_05: 0.5861 - within_eps_0_1: 0.8602 - val_log_cosh: 0.0645 - val_loss: 0.0214 - val_within_eps_0_005: 0.0158 - val_within_eps_0_01: 0.0313 - val_within_eps_0_02: 0.0622 - val_within_eps_0_05: 0.1549 - val_within_eps_0_1: 0.2989
# Epoch 22/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0025 - loss: 0.0022 - within_eps_0_005: 0.0697 - within_eps_0_01: 0.1387 - within_eps_0_02: 0.2718 - within_eps_0_05: 0.5942 - within_eps_0_1: 0.8661 - val_log_cosh: 0.0647 - val_loss: 0.0215 - val_within_eps_0_005: 0.0157 - val_within_eps_0_01: 0.0311 - val_within_eps_0_02: 0.0624 - val_within_eps_0_05: 0.1572 - val_within_eps_0_1: 0.2996
# Epoch 23/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - log_cosh: 0.0024 - loss: 0.0021 - within_eps_0_005: 0.0709 - within_eps_0_01: 0.1408 - within_eps_0_02: 0.2759 - within_eps_0_05: 0.6025 - within_eps_0_1: 0.8720 - val_log_cosh: 0.0667 - val_loss: 0.0221 - val_within_eps_0_005: 0.0153 - val_within_eps_0_01: 0.0306 - val_within_eps_0_02: 0.0618 - val_within_eps_0_05: 0.1551 - val_within_eps_0_1: 0.2908
# Epoch 24/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - log_cosh: 0.0023 - loss: 0.0021 - within_eps_0_005: 0.0728 - within_eps_0_01: 0.1445 - within_eps_0_02: 0.2817 - within_eps_0_05: 0.6093 - within_eps_0_1: 0.8762 - val_log_cosh: 0.0705 - val_loss: 0.0232 - val_within_eps_0_005: 0.0152 - val_within_eps_0_01: 0.0302 - val_within_eps_0_02: 0.0608 - val_within_eps_0_05: 0.1482 - val_within_eps_0_1: 0.2769
# Epoch 25/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - log_cosh: 0.0022 - loss: 0.0020 - within_eps_0_005: 0.0731 - within_eps_0_01: 0.1449 - within_eps_0_02: 0.2832 - within_eps_0_05: 0.6139 - within_eps_0_1: 0.8797 - val_log_cosh: 0.0690 - val_loss: 0.0227 - val_within_eps_0_005: 0.0148 - val_within_eps_0_01: 0.0301 - val_within_eps_0_02: 0.0595 - val_within_eps_0_05: 0.1498 - val_within_eps_0_1: 0.2848
# Epoch 26/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - log_cosh: 0.0022 - loss: 0.0020 - within_eps_0_005: 0.0750 - within_eps_0_01: 0.1489 - within_eps_0_02: 0.2909 - within_eps_0_05: 0.6239 - within_eps_0_1: 0.8853 - val_log_cosh: 0.0674 - val_loss: 0.0222 - val_within_eps_0_005: 0.0154 - val_within_eps_0_01: 0.0310 - val_within_eps_0_02: 0.0620 - val_within_eps_0_05: 0.1561 - val_within_eps_0_1: 0.2882
# Epoch 27/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0021 - loss: 0.0019 - within_eps_0_005: 0.0758 - within_eps_0_01: 0.1501 - within_eps_0_02: 0.2928 - within_eps_0_05: 0.6277 - within_eps_0_1: 0.8875 - val_log_cosh: 0.0700 - val_loss: 0.0230 - val_within_eps_0_005: 0.0147 - val_within_eps_0_01: 0.0295 - val_within_eps_0_02: 0.0594 - val_within_eps_0_05: 0.1488 - val_within_eps_0_1: 0.2787
#   -> min val_log_cosh=0.061892621219 | min val_huber=0.020658794791
#
# --- Entrenando δ=0.13649090826511381 ---
# Epoch 1/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - log_cosh: 0.2961 - loss: 0.0840 - within_eps_0_005: 0.0050 - within_eps_0_01: 0.0100 - within_eps_0_02: 0.0201 - within_eps_0_05: 0.0500 - within_eps_0_1: 0.0997 - val_log_cosh: 0.1717 - val_loss: 0.0570 - val_within_eps_0_005: 0.0072 - val_within_eps_0_01: 0.0143 - val_within_eps_0_02: 0.0290 - val_within_eps_0_05: 0.0743 - val_within_eps_0_1: 0.1485
# Epoch 2/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - log_cosh: 0.1376 - loss: 0.0518 - within_eps_0_005: 0.0074 - within_eps_0_01: 0.0146 - within_eps_0_02: 0.0291 - within_eps_0_05: 0.0727 - within_eps_0_1: 0.1447 - val_log_cosh: 0.1042 - val_loss: 0.0388 - val_within_eps_0_005: 0.0125 - val_within_eps_0_01: 0.0253 - val_within_eps_0_02: 0.0504 - val_within_eps_0_05: 0.1271 - val_within_eps_0_1: 0.2441
# Epoch 3/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - log_cosh: 0.1000 - loss: 0.0422 - within_eps_0_005: 0.0087 - within_eps_0_01: 0.0174 - within_eps_0_02: 0.0346 - within_eps_0_05: 0.0863 - within_eps_0_1: 0.1714 - val_log_cosh: 0.0870 - val_loss: 0.0340 - val_within_eps_0_005: 0.0131 - val_within_eps_0_01: 0.0264 - val_within_eps_0_02: 0.0521 - val_within_eps_0_05: 0.1285 - val_within_eps_0_1: 0.2563
# Epoch 4/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0704 - loss: 0.0336 - within_eps_0_005: 0.0106 - within_eps_0_01: 0.0211 - within_eps_0_02: 0.0419 - within_eps_0_05: 0.1051 - within_eps_0_1: 0.2078 - val_log_cosh: 0.0777 - val_loss: 0.0317 - val_within_eps_0_005: 0.0137 - val_within_eps_0_01: 0.0270 - val_within_eps_0_02: 0.0541 - val_within_eps_0_05: 0.1323 - val_within_eps_0_1: 0.2555
# Epoch 5/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0474 - loss: 0.0258 - within_eps_0_005: 0.0131 - within_eps_0_01: 0.0262 - within_eps_0_02: 0.0522 - within_eps_0_05: 0.1294 - within_eps_0_1: 0.2553 - val_log_cosh: 0.0781 - val_loss: 0.0316 - val_within_eps_0_005: 0.0137 - val_within_eps_0_01: 0.0279 - val_within_eps_0_02: 0.0559 - val_within_eps_0_05: 0.1388 - val_within_eps_0_1: 0.2631
# Epoch 6/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - log_cosh: 0.0304 - loss: 0.0190 - within_eps_0_005: 0.0165 - within_eps_0_01: 0.0332 - within_eps_0_02: 0.0662 - within_eps_0_05: 0.1650 - within_eps_0_1: 0.3214 - val_log_cosh: 0.0776 - val_loss: 0.0315 - val_within_eps_0_005: 0.0149 - val_within_eps_0_01: 0.0299 - val_within_eps_0_02: 0.0597 - val_within_eps_0_05: 0.1404 - val_within_eps_0_1: 0.2653
# Epoch 7/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - log_cosh: 0.0185 - loss: 0.0133 - within_eps_0_005: 0.0214 - within_eps_0_01: 0.0431 - within_eps_0_02: 0.0865 - within_eps_0_05: 0.2143 - within_eps_0_1: 0.4117 - val_log_cosh: 0.0721 - val_loss: 0.0297 - val_within_eps_0_005: 0.0144 - val_within_eps_0_01: 0.0295 - val_within_eps_0_02: 0.0592 - val_within_eps_0_05: 0.1474 - val_within_eps_0_1: 0.2776
# Epoch 8/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0111 - loss: 0.0090 - within_eps_0_005: 0.0291 - within_eps_0_01: 0.0580 - within_eps_0_02: 0.1146 - within_eps_0_05: 0.2803 - within_eps_0_1: 0.5218 - val_log_cosh: 0.0713 - val_loss: 0.0293 - val_within_eps_0_005: 0.0154 - val_within_eps_0_01: 0.0312 - val_within_eps_0_02: 0.0640 - val_within_eps_0_05: 0.1567 - val_within_eps_0_1: 0.2939
# Epoch 9/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - log_cosh: 0.0071 - loss: 0.0062 - within_eps_0_005: 0.0374 - within_eps_0_01: 0.0742 - within_eps_0_02: 0.1473 - within_eps_0_05: 0.3550 - within_eps_0_1: 0.6315 - val_log_cosh: 0.0679 - val_loss: 0.0283 - val_within_eps_0_005: 0.0175 - val_within_eps_0_01: 0.0346 - val_within_eps_0_02: 0.0678 - val_within_eps_0_05: 0.1583 - val_within_eps_0_1: 0.2937
# Epoch 10/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - log_cosh: 0.0054 - loss: 0.0048 - within_eps_0_005: 0.0439 - within_eps_0_01: 0.0876 - within_eps_0_02: 0.1743 - within_eps_0_05: 0.4139 - within_eps_0_1: 0.7054 - val_log_cosh: 0.0651 - val_loss: 0.0275 - val_within_eps_0_005: 0.0164 - val_within_eps_0_01: 0.0322 - val_within_eps_0_02: 0.0630 - val_within_eps_0_05: 0.1529 - val_within_eps_0_1: 0.2869
# Epoch 11/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - log_cosh: 0.0045 - loss: 0.0041 - within_eps_0_005: 0.0486 - within_eps_0_01: 0.0975 - within_eps_0_02: 0.1929 - within_eps_0_05: 0.4533 - within_eps_0_1: 0.7479 - val_log_cosh: 0.0616 - val_loss: 0.0266 - val_within_eps_0_005: 0.0152 - val_within_eps_0_01: 0.0306 - val_within_eps_0_02: 0.0612 - val_within_eps_0_05: 0.1505 - val_within_eps_0_1: 0.2880
# Epoch 12/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0040 - loss: 0.0037 - within_eps_0_005: 0.0519 - within_eps_0_01: 0.1034 - within_eps_0_02: 0.2049 - within_eps_0_05: 0.4757 - within_eps_0_1: 0.7705 - val_log_cosh: 0.0610 - val_loss: 0.0264 - val_within_eps_0_005: 0.0154 - val_within_eps_0_01: 0.0300 - val_within_eps_0_02: 0.0608 - val_within_eps_0_05: 0.1503 - val_within_eps_0_1: 0.2905
# Epoch 13/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0037 - loss: 0.0034 - within_eps_0_005: 0.0541 - within_eps_0_01: 0.1085 - within_eps_0_02: 0.2145 - within_eps_0_05: 0.4946 - within_eps_0_1: 0.7885 - val_log_cosh: 0.0621 - val_loss: 0.0269 - val_within_eps_0_005: 0.0153 - val_within_eps_0_01: 0.0307 - val_within_eps_0_02: 0.0616 - val_within_eps_0_05: 0.1515 - val_within_eps_0_1: 0.2913
# Epoch 14/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0034 - loss: 0.0032 - within_eps_0_005: 0.0571 - within_eps_0_01: 0.1138 - within_eps_0_02: 0.2240 - within_eps_0_05: 0.5110 - within_eps_0_1: 0.8031 - val_log_cosh: 0.0615 - val_loss: 0.0268 - val_within_eps_0_005: 0.0144 - val_within_eps_0_01: 0.0291 - val_within_eps_0_02: 0.0587 - val_within_eps_0_05: 0.1511 - val_within_eps_0_1: 0.2877
# Epoch 15/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - log_cosh: 0.0032 - loss: 0.0030 - within_eps_0_005: 0.0582 - within_eps_0_01: 0.1160 - within_eps_0_02: 0.2296 - within_eps_0_05: 0.5232 - within_eps_0_1: 0.8156 - val_log_cosh: 0.0640 - val_loss: 0.0278 - val_within_eps_0_005: 0.0142 - val_within_eps_0_01: 0.0282 - val_within_eps_0_02: 0.0566 - val_within_eps_0_05: 0.1450 - val_within_eps_0_1: 0.2755
# Epoch 16/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0031 - loss: 0.0029 - within_eps_0_005: 0.0605 - within_eps_0_01: 0.1203 - within_eps_0_02: 0.2368 - within_eps_0_05: 0.5363 - within_eps_0_1: 0.8242 - val_log_cosh: 0.0651 - val_loss: 0.0281 - val_within_eps_0_005: 0.0145 - val_within_eps_0_01: 0.0286 - val_within_eps_0_02: 0.0565 - val_within_eps_0_05: 0.1453 - val_within_eps_0_1: 0.2782
# Epoch 17/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0029 - loss: 0.0028 - within_eps_0_005: 0.0616 - within_eps_0_01: 0.1228 - within_eps_0_02: 0.2415 - within_eps_0_05: 0.5452 - within_eps_0_1: 0.8328 - val_log_cosh: 0.0663 - val_loss: 0.0285 - val_within_eps_0_005: 0.0141 - val_within_eps_0_01: 0.0283 - val_within_eps_0_02: 0.0566 - val_within_eps_0_05: 0.1440 - val_within_eps_0_1: 0.2794
# Epoch 18/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - log_cosh: 0.0028 - loss: 0.0027 - within_eps_0_005: 0.0634 - within_eps_0_01: 0.1259 - within_eps_0_02: 0.2479 - within_eps_0_05: 0.5554 - within_eps_0_1: 0.8408 - val_log_cosh: 0.0652 - val_loss: 0.0282 - val_within_eps_0_005: 0.0144 - val_within_eps_0_01: 0.0288 - val_within_eps_0_02: 0.0580 - val_within_eps_0_05: 0.1441 - val_within_eps_0_1: 0.2735
# Epoch 19/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0027 - loss: 0.0026 - within_eps_0_005: 0.0640 - within_eps_0_01: 0.1276 - within_eps_0_02: 0.2511 - within_eps_0_05: 0.5633 - within_eps_0_1: 0.8477 - val_log_cosh: 0.0659 - val_loss: 0.0283 - val_within_eps_0_005: 0.0145 - val_within_eps_0_01: 0.0290 - val_within_eps_0_02: 0.0596 - val_within_eps_0_05: 0.1524 - val_within_eps_0_1: 0.2817
# Epoch 20/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0026 - loss: 0.0025 - within_eps_0_005: 0.0660 - within_eps_0_01: 0.1311 - within_eps_0_02: 0.2573 - within_eps_0_05: 0.5725 - within_eps_0_1: 0.8538 - val_log_cosh: 0.0747 - val_loss: 0.0317 - val_within_eps_0_005: 0.0126 - val_within_eps_0_01: 0.0252 - val_within_eps_0_02: 0.0506 - val_within_eps_0_05: 0.1262 - val_within_eps_0_1: 0.2422
# Epoch 21/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0025 - loss: 0.0024 - within_eps_0_005: 0.0677 - within_eps_0_01: 0.1342 - within_eps_0_02: 0.2637 - within_eps_0_05: 0.5832 - within_eps_0_1: 0.8603 - val_log_cosh: 0.0709 - val_loss: 0.0302 - val_within_eps_0_005: 0.0146 - val_within_eps_0_01: 0.0285 - val_within_eps_0_02: 0.0561 - val_within_eps_0_05: 0.1373 - val_within_eps_0_1: 0.2555
# Epoch 22/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - log_cosh: 0.0024 - loss: 0.0023 - within_eps_0_005: 0.0681 - within_eps_0_01: 0.1358 - within_eps_0_02: 0.2666 - within_eps_0_05: 0.5890 - within_eps_0_1: 0.8654 - val_log_cosh: 0.0704 - val_loss: 0.0299 - val_within_eps_0_005: 0.0149 - val_within_eps_0_01: 0.0297 - val_within_eps_0_02: 0.0585 - val_within_eps_0_05: 0.1444 - val_within_eps_0_1: 0.2631
# Epoch 23/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - log_cosh: 0.0023 - loss: 0.0022 - within_eps_0_005: 0.0699 - within_eps_0_01: 0.1389 - within_eps_0_02: 0.2719 - within_eps_0_05: 0.5955 - within_eps_0_1: 0.8709 - val_log_cosh: 0.0728 - val_loss: 0.0308 - val_within_eps_0_005: 0.0126 - val_within_eps_0_01: 0.0259 - val_within_eps_0_02: 0.0527 - val_within_eps_0_05: 0.1323 - val_within_eps_0_1: 0.2492
# Epoch 24/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - log_cosh: 0.0023 - loss: 0.0022 - within_eps_0_005: 0.0713 - within_eps_0_01: 0.1415 - within_eps_0_02: 0.2768 - within_eps_0_05: 0.6037 - within_eps_0_1: 0.8760 - val_log_cosh: 0.0717 - val_loss: 0.0301 - val_within_eps_0_005: 0.0158 - val_within_eps_0_01: 0.0312 - val_within_eps_0_02: 0.0626 - val_within_eps_0_05: 0.1491 - val_within_eps_0_1: 0.2688
# Epoch 25/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - log_cosh: 0.0023 - loss: 0.0022 - within_eps_0_005: 0.0712 - within_eps_0_01: 0.1413 - within_eps_0_02: 0.2769 - within_eps_0_05: 0.6041 - within_eps_0_1: 0.8763 - val_log_cosh: 0.0790 - val_loss: 0.0331 - val_within_eps_0_005: 0.0118 - val_within_eps_0_01: 0.0243 - val_within_eps_0_02: 0.0494 - val_within_eps_0_05: 0.1227 - val_within_eps_0_1: 0.2307
# Epoch 26/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - log_cosh: 0.0021 - loss: 0.0021 - within_eps_0_005: 0.0728 - within_eps_0_01: 0.1452 - within_eps_0_02: 0.2850 - within_eps_0_05: 0.6167 - within_eps_0_1: 0.8848 - val_log_cosh: 0.0756 - val_loss: 0.0317 - val_within_eps_0_005: 0.0124 - val_within_eps_0_01: 0.0254 - val_within_eps_0_02: 0.0516 - val_within_eps_0_05: 0.1320 - val_within_eps_0_1: 0.2469
# Epoch 27/160
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - log_cosh: 0.0021 - loss: 0.0020 - within_eps_0_005: 0.0734 - within_eps_0_01: 0.1458 - within_eps_0_02: 0.2848 - within_eps_0_05: 0.6183 - within_eps_0_1: 0.8857 - val_log_cosh: 0.0819 - val_loss: 0.0339 - val_within_eps_0_005: 0.0115 - val_within_eps_0_01: 0.0234 - val_within_eps_0_02: 0.0481 - val_within_eps_0_05: 0.1216 - val_within_eps_0_1: 0.2266
#   -> min val_log_cosh=0.060980796814 | min val_huber=0.026354439557
#
# Tabla val_log_cosh(min) por δ (orden asc):
#   δ=0.0279375: val_log_cosh=0.058244042099 | val_huber=0.006391924806
#   δ=0.136491: val_log_cosh=0.060980796814 | val_huber=0.026354439557
#   δ=     0.1: val_log_cosh=0.061892621219 | val_huber=0.020658794791
#   δ=    0.01: val_log_cosh=0.073388434947 | val_huber=0.002776667941
#   δ=    0.02: val_log_cosh=0.073430567980 | val_huber=0.005453315098
#   δ=0.0568381: val_log_cosh=0.075663596392 | val_huber=0.014974293299
#   δ=    0.05: val_log_cosh=0.075860828161 | val_huber=0.013042463921
#   δ=0.0992432: val_log_cosh=0.081575222313 | val_huber=0.024856651202
#
# >>> Mejor δ por val_log_cosh: 0.02793753147125244 (val_log_cosh=0.058244042099)
#
# Resultados TEST - Escenario L (GRU)
#   loss (Huber):              0.052311
#   log_cosh:                  1.531102
#   within_eps_0_005          : 0.002755
#   within_eps_0_01           : 0.005682
#   within_eps_0_02           : 0.012013
#   within_eps_0_05           : 0.032728
#   within_eps_0_1            : 0.070148
#   AUTC[0.005–0.100]:         0.035290
#
# === Mejor δ por escenario (GRU, métrica común: val_log_cosh) ===
#   S: 0.017357412725687027  -> ./models_gru_huber_sweep/gru_huber_w20_h1_delta0_01735741273_S.keras
#   M: 0.1  -> ./models_gru_huber_sweep/gru_huber_w60_h5_delta0_1_M.keras
#   L: 0.02793753147125244  -> ./models_gru_huber_sweep/gru_huber_w120_h20_delta0_02793753147_L.keras
